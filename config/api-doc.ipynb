# %% [markdown]
# **Google Gemini API (via Google AI Studio) provides official OpenAI-compatible REST endpoints.** This lets you use the standard OpenAI client libraries or raw REST calls with minimal changes.
#
# ### Key Details
# - **Base URL**: `https://generativelanguage.googleapis.com/v1beta/openai/`
# - **Authentication**: Use a Gemini API key (get it from [Google AI Studio](https://aistudio.google.com/apikey)) passed as a Bearer token.
# - **Models**: Use Gemini model names like `gemini-3-flash-preview`, `gemini-2.5-flash`, etc. (check the latest available models in the docs or via the `/models` endpoint).
# - **Main endpoint**: `POST /chat/completions` (and others like embeddings).
#
# ### Standard REST Example (curl)
# ```bash
# curl "https://generativelanguage.googleapis.com/v1beta/openai/chat/completions" \
#   -H "Content-Type: application/json" \
#   -H "Authorization: Bearer $GEMINI_API_KEY" \
#   -d '{
#     "model": "gemini-3-flash-preview",
#     "messages": [
#       {
#         "role": "user",
#         "content": "Explain to me how AI works"
#       }
#     ]
#   }'
# ```
#
# ### Python (OpenAI Library)
# ```python
# from openai import OpenAI
#
# client = OpenAI(
#     api_key="YOUR_GEMINI_API_KEY",
#     base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
# )
#
# response = client.chat.completions.create(
#     model="gemini-3-flash-preview",
#     messages=[
#         {"role": "system", "content": "You are a helpful assistant."},
#         {"role": "user", "content": "Explain to me how AI works"}
#     ]
# )
#
# print(response.choices[0].message.content)
# ```
#
# ### Supported Features (as of latest docs)
# - **Streaming** — Add `"stream": true`.
# - **Function/tool calling** — Standard OpenAI `tools` and `tool_choice`.
# - **Image understanding (multimodal)** — Send images via base64 or URLs in messages.
# - **Reasoning/Thinking** — Use `reasoning_effort` (e.g., "low", "medium", "high", "none") or `extra_body` for Gemini-specific params.
# - **Structured outputs**, embeddings, and more.
#
# **Note**: Not every OpenAI feature is 100% supported yet (it's a compatibility layer). For advanced Gemini-specific features, use the native Gemini SDK or add them via `extra_body`. Check the official docs for the latest supported parameters and model list.
#
# For full details, including examples for images, streaming, tools, and limitations, visit: [https://ai.google.dev/gemini-api/docs/openai](https://ai.google.dev/gemini-api/docs/openai).
#
# This setup works great for switching from OpenAI to Gemini with very little code change.
